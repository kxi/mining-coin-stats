# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
COIN_BLOCK_INFO_PATH = "coin_block_info"

coin = "RVN"
fname = os.path.join(COIN_BLOCK_INFO_PATH, coin+"_block_info.csv")

df = pd.read_csv(fname)

# %%
df.head(10)
# Out:
#      difficulty    height         nonce          time
# 0  24111.458454  198693.0  4.155096e+08  1.525521e+09
# 1  24111.458454  198692.0  1.973066e+09  1.525521e+09
# 2  24111.458454  198691.0  2.023284e+09  1.525521e+09
# 3  24111.458454  198690.0  4.125593e+09  1.525521e+09
# 4  24111.458454  198689.0  2.588771e+09  1.525521e+09
# 5  24111.458454  198688.0  5.317032e+07  1.525521e+09
# 6  24111.458454  198687.0  3.316935e+09  1.525521e+09
# 7  24111.458454  198686.0  3.938550e+09  1.525521e+09
# 8  24111.458454  198685.0  1.693880e+09  1.525521e+09
# 9  24111.458454  198684.0  1.362525e+09  1.525521e+09

# %%
df['date'] = pd.to_datetime(df['time'],unit='s')

# %%
df.size
# Out:
# 2140

# %%
# Out:
# 1

# %%
df_block_rate = df[['height','time']]

# %%
# df_block_rate['index']=df_block_rate['height']

# %%
# df_block_rate.loc['index']=df_block_rate['height']

# %%
df_block_rate.head(3)
# Out:
#     height          time
# 0  45603.0  1.525518e+09
# 1  45602.0  1.525518e+09
# 2  45601.0  1.525518e+09

# %%
# df_block_rate = df_block_rate.set_index('index').diff(-280).dropna()

# %%
df_block_rate = df_block_rate.diff(-400).dropna()

# %%
df_block_rate.head(3)
# Out:
#    height     time
# 0   400.0  29176.0
# 1   400.0  29155.0
# 2   400.0  29137.0

# %%
df_block_rate['block_per_day']=df_block_rate['height']/df_block_rate['time']*3600*24

# %%
df_block_rate
# Out:
#      height     time  block_per_day
# 0     400.0  29176.0    1184.535234
# 1     400.0  29155.0    1185.388441
# 2     400.0  29137.0    1186.120740
# 3     400.0  29114.0    1187.057773
# 4     400.0  29068.0    1188.936287
# 5     400.0  29108.0    1187.302460
# 6     400.0  29067.0    1188.977191
# 7     400.0  29003.0    1191.600869
# 8     400.0  28889.0    1196.303091
# 9     400.0  28312.0    1220.683809
# 10    400.0  27934.0    1237.201976
# 11    400.0  27781.0    1244.015694
# 12    400.0  27736.0    1246.034035
# 13    400.0  27711.0    1247.158168
# 14    400.0  27677.0    1248.690248
# 15    400.0  27673.0    1248.870740
# 16    400.0  27615.0    1251.493753
# 17    400.0  27616.0    1251.448436
# 18    400.0  27606.0    1251.901760
# 19    400.0  27624.0    1251.086012
# 20    400.0  27670.0    1249.006144
# 21    400.0  27807.0    1242.852519
# 22    400.0  27818.0    1242.361061
# 23    400.0  27994.0    1234.550261
# 24    400.0  28790.0    1200.416811
# 25    400.0  28804.0    1199.833356
# 26    400.0  28968.0    1193.040597
# 27    400.0  29093.0    1187.914619
# 28    400.0  29132.0    1186.324317
# 29    400.0  29111.0    1187.180104
# ..      ...      ...            ...
# 495   400.0  27425.0    1260.164084
# 496   400.0  27404.0    1261.129762
# 497   400.0  27403.0    1261.175784
# 498   400.0  27349.0    1263.665948
# 499   400.0  27253.0    1268.117271
# 500   400.0  27322.0    1264.914721
# 501   400.0  26902.0    1284.662850
# 502   400.0  26432.0    1307.506053
# 503   400.0  26419.0    1308.149438
# 504   400.0  26447.0    1306.764472
# 505   400.0  26432.0    1307.506053
# 506   400.0  26438.0    1307.209320
# 507   400.0  26423.0    1307.951406
# 508   400.0  26380.0    1310.083397
# 509   400.0  26416.0    1308.298001
# 510   400.0  26382.0    1309.984080
# 511   400.0  26394.0    1309.388497
# 512   400.0  26395.0    1309.338890
# 513   400.0  26423.0    1307.951406
# 514   400.0  26461.0    1306.073089
# 515   400.0  26639.0    1297.345996
# 516   400.0  26492.0    1304.544768
# 517   400.0  26358.0    1311.176872
# 518   400.0  26341.0    1312.023082
# 519   400.0  26239.0    1317.123366
# 520   400.0  26227.0    1317.726008
# 521   400.0  26225.0    1317.826501
# 522   400.0  26293.0    1314.418286
# 523   400.0  26394.0    1309.388497
# 524   400.0  26425.0    1307.852412
#
# [525 rows x 3 columns]

# %%
fig = plt.figure(figsize=(20,10))
x_axis = df_block_rate['height']
y_axis = df_block_rate['block_per_day']
plt.plot(y_axis)
# plt.plot(x_axis, y_axis)
# fig.suptitle('Block_Speed vs Block Height', fontsize=20)
# plt.xlabel('Block Height', fontsize=18)
# plt.ylabel('Block Speed', fontsize=18)

# %%
block_speed_latest = int(df_block_rate['block_per_day'][0])

# %%
print("Coin [{}] Block Speed is {} Blocks/Day".format(coin, block_speed_latest))
# Out:
# Coin [EXVO] Block Speed is 1184 Blocks/Day
