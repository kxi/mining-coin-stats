# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
COIN_NETHA_INFO_PATH = "coin_nethash_info"

coin = "EXVO"
# coin = "RVN"
# coin = "PGN"
# coin = "LUX"
# coin = "PROTON"
# coin = "RDEN"
# coin = "SPD"

fname = os.path.join(COIN_BLOCK_INFO_PATH, coin+"_nethash_info.csv")

# %%
df = pd.read_csv(fname)

# %%
print("Number of Nethash Sample: {}".format(df.count()[0]))
# Out:
# Number of Nethash Sample: 485

# %%
print("Latest Block: {}".format(int(df["height"][0])))
# Out:
# Latest Block: 46762

# %%
df.head(5)
# Out:
#    height      nethash
# 0   46762  16005351397
# 1   46761  16266591253
# 2   46760  16347160678
# 3   46759  16845465793
# 4   46755  16846293996

# %%
MA_window = min(15, int((df.count()[0]-1)*0.5))
print("MA Windows = {}".format(MA_window))
# Out:
# MA Windows = 15

# %%
df_ma = df.rolling(window=MA_window).mean()
df_ma.head(10)
# Out:
#    height  nethash
# 0     NaN      NaN
# 1     NaN      NaN
# 2     NaN      NaN
# 3     NaN      NaN
# 4     NaN      NaN
# 5     NaN      NaN
# 6     NaN      NaN
# 7     NaN      NaN
# 8     NaN      NaN
# 9     NaN      NaN

# %%
df.head(10)
# Out:
#    height      nethash
# 0   46762  16005351397
# 1   46761  16266591253
# 2   46760  16347160678
# 3   46759  16845465793
# 4   46755  16846293996
# 5   46753  16809123713
# 6   46751  16590590642
# 7   46750  16614500612
# 8   46749  16489877705
# 9   46748  16854307007

# %%
fig = plt.figure(figsize=(20,10))
x_axis = df['height']
y_axis = df['nethash']
y_axis_ma = df_ma['nethash']

plt.plot(x_axis, y_axis)
plt.plot(x_axis, y_axis_ma)

# plt.plot(x_axis, y_axis)
# fig.suptitle('Block_Speed vs Block Height', fontsize=20)
# plt.xlabel('Block Height', fontsize=18)
# plt.ylabel('Block Speed', fontsize=18)

# %%
nethash_latest = int(df['nethash'][0])
nethash_mv = int(df_ma['nethash'].dropna().head((1)))

# %%
print("Coin [{}] Recent Nethash is {}".format(coin, nethash_latest))
print("Coin [{}] Nethash MA is {}".format(coin, nethash_mv))
# Out:
# Coin [EXVO] Recent Nethash is 16005351397
# Coin [EXVO] Nethash MA is 16677625949
